# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 187.9 kB/s eta 0:03:27
#    ---------------------------------------- 0.0/38.8 MB 163.4 kB/s eta 0:03:58
#    ---------------------------------------- 0.0/38.8 MB 163.4 kB/s eta 0:03:58
#    ---------------------------------------- 0.0/38.8 MB 163.4 kB/s eta 0:03:58
#    ---------------------------------------- 0.1/38.8 MB 163.6 kB/s eta 0:03:58
#    ---------------------------------------- 0.1/38.8 MB 178.6 kB/s eta 0:03:38
# ...

# %%
import cv2 
img = cv2.imread("./images/app.jfif")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
cv2.imshow("app.jfif", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resize=cv2.resize(img,(1000,600))
cv2.imshow("app.jfif", resize)
cv2.waitKey(0)
cv2.destroyAllWindows()
