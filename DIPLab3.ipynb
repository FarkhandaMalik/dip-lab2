# %% [markdown]
# <a href="https://colab.research.google.com/github/FarkhandaMalik/dip-lab2/blob/main/DIPLab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Task 1**

# %%
import cv2

image = cv2.imread('audig63.jpg')

height, width, channels = image.shape

print("Height: ", height)
print("width: ", width)
print("channels: ", channels)
# Out:
# Height:  386
# width:  686
# channels:  3

# %%
from PIL import Image
import os
import time

img_path = 'audig63.jpg'
image = Image.open(img_path)

size = os.path.getsize(img_path)
width, height = image.size
mode = image.mode
bit_depth = image.bits
creation_time = time.ctime(os.path.getctime(img_path))

print(f"Size: {round((size / 1024), 2)} Mega bytes")
print(f"Creation Date: {creation_time}")
print(f"Mode (Coding Method): {mode}")
print(f"Bit Depth: {bit_depth}")
print(f"Width: {width}")
print(f"Height: {height}")
# Out:
# Size: 94.05 Mega bytes
# Creation Date: Thu Oct  3 18:25:48 2024
# Mode (Coding Method): RGB
# Bit Depth: 8
# Width: 686
# Height: 386

# %%
import numpy as np

double_array = np.array([-100.5, 0, 50.3, 255.9, 300.1, 500])

uint8_array = double_array.astype(np.uint8)

print("Original array:", double_array)
print("Converted to uint8:", uint8_array)
# Out:
# Original array: [-100.5    0.    50.3  255.9  300.1  500. ]
# Converted to uint8: [156   0  50 255  44 244]

# %%
import cv2
import matplotlib.pyplot as plt

image_path = 'audig63.jpg'
image = cv2.imread(image_path)

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)


plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(binary_image, cmap='gray')
plt.title("Binarized Image (Threshold = 127)")

plt.show()

# %% [markdown]
# # **Task 2**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

def manual_binarize(image, threshold):
    height, width = image.shape
    binarized_image = np.zeros((height, width), dtype=np.uint8)

    for i in range(height):
        for j in range(width):
            if image[i, j] > threshold:
                binarized_image[i, j] = 255
            else:
                binarized_image[i, j] = 0

    return binarized_image

input_image = cv2.imread('audig63.jpg')
height, width, channels = input_image.shape

if channels == 3:
    print("The image is a three-channel (color) image.")
    gray_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)
    threshold_value = 128
    binarized_image = manual_binarize(gray_image, threshold_value)
    cv2_imshow(binarized_image)  # Use cv2_imshow to display the binarized image

elif channels == 1:
    print("The image is a one-channel (grayscale) image.")
    cv2_imshow(input_image)  # Use cv2_imshow to display the grayscale image

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# The image is a three-channel (color) image.
# <PIL.Image.Image image mode=L size=686x386>

# %% [markdown]
# ## **Task 4**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow  # Use this for image display in Colab/Jupyter

def manual_binarize(image, threshold):
    height, width = image.shape
    binarized_image = np.zeros((height, width), dtype=np.uint8)

    for i in range(height):
        for j in range(width):
            if image[i, j] > threshold:
                binarized_image[i, j] = 255
            else:
                binarized_image[i, j] = 0

    return binarized_image

input_image = cv2.imread('audig63.jpg')

gray_image = np.zeros((input_image.shape[0], input_image.shape[1]), dtype=np.uint8)

# Manually convert to grayscale
for i in range(input_image.shape[0]):
    for j in range(input_image.shape[1]):
        b, g, r = input_image[i, j]
        gray_intensity = int(0.299 * r + 0.587 * g + 0.114 * b)
        gray_image[i, j] = gray_intensity

# Binarize image
threshold_value = 128
binarized_image = manual_binarize(gray_image, threshold_value)

# Display the binarized image using cv2_imshow
cv2_imshow(binarized_image)
# Out:
# <PIL.Image.Image image mode=L size=686x386>

# %% [markdown]
# ## **Task 5**

# %%
import numpy as np
import cv2 as cv

cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    ret, frame = cap.read()

    if not ret:
        print("Can't receive frame?")
        print("Exit")
        break
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    cv.imshow('frame', gray)
    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# Cannot open camera
# Can't receive frame?
# Exit
